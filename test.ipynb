# %%
import pandas as pd

# Replace 'your_file.csv' with the path to your CSV file
df_old = pd.read_csv('/Users/sunilshah/Development/OSPO/institutional-innovation-grapher/outputs/github-account-list-george-washington-university-2025-09-05-fulldetail.csv')
print(f"Number of rows for old df: {len(df_old)}")
# Out:
# Number of rows for old df: 918

# %%
# Replace 'your_file.csv' with the path to your CSV file
df_new = pd.read_csv('/Users/sunilshah/Development/OSPO/institutional-innovation-grapher/outputs/github-account-list-george-washington-university-2025-09-09-fulldetail.csv')
print(f"Number of rows for new df: {len(df_new)}")
# Out:
# Number of rows for new df: 917

# %%
participants = [
    "David Lippert",
    "Rosemary Pauley",
    "Matthew Mihalik",
    "Ryan Engstrom",
    "Eric Lawrence",
    "Mike Sanders",
    "Emily Blumenthal",
    "Bernard Huckenpahler",
    "Paul Ndebele",
    "James Otto",
    "Douglas Boyce",
    "Clark Gaylord",
    "Keith Crandall",
    "Laura Abate",
    "Miguel Andrade",
    "Joseph Kilgore",
    "Lorena Barba",
    "Michael Moreno",
    "Robin Delaloye",
    "Zoe Szajnfarber",
    "Poorvi Vora",
    "Jood Abdullah A Alfadhel",
    "Wesley Hancock",
    "Sara Hoover",
    "Alexa Alice Joubin",
    "Nouha Elyazidi",
    "Philippe Bardet",
    "Ali Rahnavard",
    "Yordanos Baharu",
    "Michael Mann",
    "David Broniatowski",
    "Richard Hinton",
    "Garrett Fields",
    "Madison Dias",
    "Mallory Smith",
    "Misty Trunnell",
    "Geneva Henry",
    "Susan Aaronson",
    "John Helveston",
    "Ryan Watkins",
    "John Hurst",
    "Daniel Kerchner",
    "LJ Johnson",
    "Imomotimi Imomotebegha",
    "Mia Diewald",
    "Anthony Artino",
    "Carrie Magee",
    "Gina Adam",
    "Katrina Rosseini",
    "Jeanine Johnson"
]

# %%
matched_participants = df_new[df_new['name'].isin(participants)]
print(matched_participants[['name', 'html_url']])
# Out:
#                name                         html_url
# 38   John Helveston        https://github.com/jhelvy
# 196      John Hurst      https://github.com/gwutrexl
# 597    Ryan Watkins  https://github.com/ryanrwatkins
